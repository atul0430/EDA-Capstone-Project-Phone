# %% [markdown]
# # **Project Name**    - **Phone**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Name -** Atul Badhe

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# A project analyzing phone call and network dataset focus on understanding user behavior, network performance, or even detecting fraudulent activities. These datasets, which typically track call details, user locations, and network connections, can be used to build models for forecasting call volume, optimizing network infrastructure, or identifying unusual communication patterns. By exploring these datasets, researchers and analysts can gain insights into how people communicate and how communication networks function.
#
# Understanding User Behaviour
#
# 1. Call Pattern Analysis:
# Analyze call durations, frequencies, and time-based patterns to understand user communication habits. This can reveal peak calling times, popular contacts, and typical call lengths.
# 2. Personalized Recommendations:
# Develop systems that can offer personalized communication experiences based on user call history and preferences.
# 3. Network Planning:
# Use historical call data to inform future network expansion and upgrades.
# 4. Call Detail Records (CDRs):
# These records contain information about individual calls, including caller and callee numbers, timestamps, and call durations.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# # A problem statement for phone call and network datasets could focus on identifying and addressing issues like call drop rates, network congestion, or fraudulent call patterns. It could also explore how to leverage call detail records (CDRs) to understand user behavior, predict churn, or improve network infrastructure planning.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# A key business objective for analyzing phone call and network datasets is to improve customer experience and optimize network performance. This can be achieved by identifying areas for improvement in call quality, network reliability, and customer service. Furthermore, these datasets can be used to understand customer behavior, personalize services, and drive targeted marketing campaigns.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as ap
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#    index            date  duration  item    month   network network_type
# 0      0  15/10/14 06:58    34.429  data  2014-11      data         data
# 1      1  15/10/14 06:58    13.000  call  2014-11  Vodafone       mobile
# 2      2  15/10/14 14:46    23.000  call  2014-11    Meteor       mobile
# 3      3  15/10/14 14:48     4.000  call  2014-11     Tesco       mobile
# 4      4  15/10/14 17:27     4.000  call  2014-11     Tesco       mobile

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (830, 7)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 830 entries, 0 to 829
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         830 non-null    int64
#  1   date          830 non-null    object
#  2   duration      830 non-null    float64
#  3   item          830 non-null    object
#  4   month         830 non-null    object
#  5   network       830 non-null    object
#  6   network_type  830 non-null    object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 45.5+ KB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(df[df.duplicated()])
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(df.isnull().sum())
# Out:
# index           0
# date            0
# duration        0
# item            0
# month           0
# network         0
# network_type    0
# dtype: int64

# %%
# Visualizing the missing values
sns.heatmap(df.isnull(), cbar = False)
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The given dataset is from phone network companies. We have analysis the data and insight behind it.
# Phone data is dataset for analysis of phone network users and type of service(Data & Call) they're using.
# The above Dataset has 830 Rows and 7 Columns. There are no missing values and no duplicate values in the dataset.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['index', 'date', 'duration', 'item', 'month', 'network',
#        'network_type'],
#       dtype='object')

# %%
# Dataset Describe
df.describe(include = 'all')
# Out:
#              index            date      duration  item    month   network  \
# count   830.000000             830    830.000000   830      830       830
# unique         NaN             747           NaN     3        5         9
# top            NaN  16/01/15 18:07           NaN  call  2014-11  Vodafone
# freq           NaN               6           NaN   388      230       215
# mean    414.500000             NaN    117.804036   NaN      NaN       NaN
# std     239.744656             NaN    444.129560   NaN      NaN       NaN
# min       0.000000             NaN      1.000000   NaN      NaN       NaN
# 25%     207.250000             NaN      1.000000   NaN      NaN       NaN
# 50%     414.500000             NaN     24.500000   NaN      NaN       NaN
# 75%     621.750000             NaN     55.000000   NaN      NaN       NaN
# max     829.000000             NaN  10528.000000   NaN      NaN       NaN
#
#        network_type
# count           830
# unique            6
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# 1. Index - It has index mentioned on it.
# 2. date - Date and Time is listed.
# 3. Duration - Call duration time
# 4. Item - Usage type Call or Data
# 5. Month - Name of month
# 6. Network - Type of network provider
# 7. Network_type - Mobile

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in df.columns.tolist():
  print("No. of unique values in ",i,"is",df[i].nunique(),".")
# Out:
# No. of unique values in  index is 830 .
# No. of unique values in  date is 747 .
# No. of unique values in  duration is 221 .
# No. of unique values in  item is 3 .
# No. of unique values in  month is 5 .
# No. of unique values in  network is 9 .
# No. of unique values in  network_type is 6 .

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
print(df.item.value_counts())
print(" ")
df['item'].value_counts().plot(kind='pie', color = 'g', autopct="%1.1f%%")
# Out:
# item
# call    388
# sms     292
# data    150
# Name: count, dtype: int64
# <Axes: ylabel='count'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart expresses a part-to-whole relationship in your data. It's easy to explain the percentage comparison through calls, sms and data usage. Where differenet percentage comparison comes into action pie chart is used frequently. So, I used Pie chart and which helped me to get the percentage comparision of the dependant variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From above pie chart I get to know that 388 calls are placed, 292 sms are send and 150 data users are using data services.
# In which 46.7 % users are using call serives, 35.2% user are active on sms and around 18.1% users are reguraly using data services.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Phone network is often referred to as customer attrition, or customer defection which is the rate at which the customers are lost. Telecom companies often use network sercives as a key business metrics to predict the number of customers that will leave a telecom service provider. Network is significant in the telecommunication industry because it directly affects the competitiveness of the service provider.
#
# It's easy to loss customers but too difficult to aquire one. One churned cutomer will make 3-4 customers away those might be acquired by your teleservice provider with "POWER OF WORDS".

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
print(df.item.value_counts())
print(" ")
df['network'].value_counts().plot(kind='bar', color = ['violet','indigo','b','g','y','orange','r'])
plt.rcParams['figure.figsize'] = (16, 9)
# Out:
# item
# call    388
# sms     292
# data    150
# Name: count, dtype: int64

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart shows different network providers and calls, sms and data services used by customers from this network providers.
# Network providers are Vodafone, Three, data, Meteor, Tesco, landline, voicemail, world and special.
# It clearly shows total call mades from all this network providers are 388, 292 sms are sent and approx 150 data users.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It clearly shows total call mades from all this network providers are 388, 292 sms are sent and approx 150 data users.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# All network providers are doing good. But, world and special need to focus more on customer service. As, they have very less no. of users and it can have bad impact on there businees.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
df['network_type'].value_counts().plot(kind='line', figsize=(15,6), color = ['violet','indigo','b','g','y','orange','r'])
plt.rcParams['figure.figsize'] = (16, 9)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Lin chart shows specific network type and it clearly shows all type of network users.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Network types are mobile, data, ladline, vocimail, world, special. Large number of users are using services on mobile. Voicemail is the service when someone not receives the call it directly takes you to the voicemail.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization
Monthly_Network_Users = df.groupby('month')['network'].value_counts()
Monthly_Network_Users
Monthly_Network_Users.unstack().plot(kind='bar', figsize=(15, 7))
plt.title('Network Usage by Month')
plt.xlabel('Month')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This bar chart shows exact month by month usage of network and shows data of 5 months of data for all network providers and approx usage of serives.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In month of November it show there was a large number of users and slowly it's dropping month by month. But, in month of January 2015 suddenly there was little bit growth of users.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
Duration_Avg_Monthly_Count = df.groupby('duration')['month'].value_counts().groupby('duration').mean()

Duration_Avg_Monthly_Count.plot(kind='bar', figsize=(55, 20))
plt.title('Average Monthly Count of Call Durations')
plt.xlabel('Duration')
plt.ylabel('Average Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This bar chart shows data for all the month in dataset and shows approximate call timing on monthly basis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
df['month'].value_counts().plot(kind='bar', figsize=(35,10), color = ['violet','indigo','b','g','y','orange','r'])
plt.rcParams['figure.figsize'] = (16, 9)
plt.title('Monthly Users')
plt.xlabel('Month')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
df.boxplot(column= 'duration', by='network_type')
# Out:
# <Axes: title={'center': 'duration'}, xlabel='network_type'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
df.head()
# Out:
#    index            date  duration  item    month   network network_type  \
# 0      0  15/10/14 06:58    34.429  data  2014-11      data         data
# 1      1  15/10/14 06:58    13.000  call  2014-11  Vodafone       mobile
# 2      2  15/10/14 14:46    23.000  call  2014-11    Meteor       mobile
# 3      3  15/10/14 14:48     4.000  call  2014-11     Tesco       mobile
# 4      4  15/10/14 17:27     4.000  call  2014-11     Tesco       mobile
#
#    network_type_numeric
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
df_corr = df.drop(columns = ['item','network','network_type'])

# %%
# Correlation Heatmap visualization code
numeric_df_corr = df_corr.select_dtypes(include=ap.number)

# Check if there are any numeric columns left
if not numeric_df_corr.empty:
    corr = numeric_df_corr.corr()
    sns.heatmap(corr, annot=True, cmap='coolwarm')
else:
    print("No numeric columns found in the DataFrame to calculate correlation.")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A correlation matrix is a table showing correlation coefficients between variables. Each cell in the table shows the correlation between two variables. A correlation matrix is used to summarize data, as an input into a more advanced analysis, and as a diagnostic for advanced analyses. The range of correlation is [1,1].
#
# Thus to know the correlation between all the variables along with the correlation coeficients, i used correlation heatmap.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above correlation heatmap, we can see total duration and network type numeric are highly positively correlated with a value of 1.
#
#
# Rest all correlation can be depicted from the above chart.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(df)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# To effectively utilize phone call and network datasets for business objectives, a comprehensive approach is needed, including data preprocessing, exploratory analysis, feature engineering, model selection, and evaluation. This process can help businesses understand customer behavior, optimize network performance, and improve overall efficiency
#
# 1. Be proactive with communication.
# 2. Ask for feedback often.
# 3. Periodically throw Offers to retain customers.
# 4. Look at the customers facing problem in the most churning states.
# 5. Lean into best customers.
# 6. Regular Server Maintenance.
# 7. Solving Poor Network Connectivity Issue.
# 8. Define a roadmap for new customers.
# 9. Analyze churn when it happens.
# 10. Stay competitive.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Phone call and network datasets offer valuable insights into communication patterns and social networks, but also present privacy considerations. These datasets, derived from call detail records (CDRs) and other network activity, can be used to analyze human mobility, social connections, and even predict future behaviors. However, anonymization and data protection are crucial to prevent misuse and protect individual privacy.
#
# Key Aspects are :-
# 1. Communication Patterns
# 2. Mobility Analysis
# 3. Social Network Analysis
# 4. Predictive Modeling
#
# Future Directions :-
# 1. Advanced Anonymization
# 2. Cross-Dataset Analysis
# 3. Ethical Frameworks

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
